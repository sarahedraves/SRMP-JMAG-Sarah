# %%
# %run pipeline.ipynb

import lightkurve as
import matplotlib.pyplot as plt
plt.ion()

# %%
tic = "TIC 261417900"
sector = 68

# %%
lc = load_lc(tic, sector)
lc = lc.remove_outliers()

# %%
lc.scatter()
plt.xlim(3155, 3165)
# Out:
# (3155.0, 3165.0)
